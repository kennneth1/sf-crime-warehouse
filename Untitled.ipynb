# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (79 kB)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.12/site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp312-cp312-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 14.2 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: pandas
# Successfully installed pandas-3.0.3

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)   # show all columns, no truncation
pd.set_option('display.max_rows', 100)        # show more rows before truncating (adjust as needed)
pd.set_option('display.width', None)          # don't wrap wide tables
pd.set_option('display.max_colwidth', None)   # don't truncate long cell values (e.g. long text fields)

# %%
df = pd.read_csv("sf_crime.csv")

# %%
df.head(3)
# Out:
#          Row ID       Incident Datetime Incident Date Incident Time  \
# 0  152278216710  2025/10/31 05:55:00 PM    2025/10/31         17:55
# 1  148998204134  2025/06/13 12:41:00 PM    2025/06/13         12:41
# 2  152328663010  2025/11/03 02:00:00 PM    2025/11/03         14:00
#
#    Incident Year Incident Day of Week         Report Datetime  Incident ID  \
# 0           2025               Friday  2025/10/31 05:55:00 PM      1522782
# 1           2025               Friday  2025/06/13 12:46:00 PM      1489982
# 2           2025               Monday  2025/11/03 02:00:00 PM      1523286
#
#    Incident Number   CAD Number Report Type Code Report Type Description  \
# 0        250613625  253042598.0               II                 Initial
# 1        250329888  251641497.0               II                 Initial
# 2        250269557          NaN               IS      Initial Supplement
#
#   Filed Online  Incident Code Incident Category Incident Subcategory  \
# 0          NaN          16710      Drug Offense       Drug Violation
# 1          NaN           4134           Assault       Simple Assault
# 2          NaN          63010           Warrant                Other
#
#                      Incident Description            Resolution  \
# 0  Narcotics Paraphernalia, Possession of  Cite or Arrest Adult
# 1                                 Battery        Open or Active
# 2        Warrant Arrest, Local SF Warrant  Cite or Arrest Adult
#
#                      Intersection         CNN Police District  \
# 0              24TH ST \ LILAC ST  24074000.0         Mission
# 1  JOHN F SHELLEY DR \ MANSELL ST  20872000.0       Ingleside
# 2                             NaN         NaN       Out of SF
#
#   Analysis Neighborhood  Supervisor District  Supervisor District 2012  \
# 0               Mission                  9.0                       9.0
# 1          McLaren Park                  9.0                       9.0
# 2                   NaN                  NaN                       NaN
#
#     Latitude   Longitude                                Point  \
# 0  37.752270 -122.417877  POINT (-122.417877197 37.752269745)
# 1  37.718128 -122.414177  POINT (-122.414176941 37.718128204)
# 2        NaN         NaN                                  NaN
#
#                data_as_of          data_loaded_at
# 0  2025/11/04 09:37:41 AM  2025/11/05 09:59:28 AM
# 1  2025/06/14 09:37:39 AM  2025/06/15 09:53:25 AM
# 2  2025/11/04 09:37:41 AM  2025/11/05 09:59:28 AM

# %%
filtered = df[
    df['Incident Category'].notna() &
    df['Latitude'].notna() &
    df['Longitude'].notna() &
    df['Analysis Neighborhood'].notna() &
    df['Intersection'].notna() &
    (df['Police District'] != 'Out of SF')
]

# %%
filtered[['Intersection', 'Analysis Neighborhood', 'Police District']].drop_duplicates()
# Out:
#                                           Intersection  \
# 0                                   24TH ST \ LILAC ST
# 1                       JOHN F SHELLEY DR \ MANSELL ST
# 4                               38TH AVE \ CABRILLO ST
# 5                              LARKIN ST \ OFARRELL ST
# 6                                 GOUGH ST \ HAIGHT ST
# ...                                                ...
# 1004292  FORT MASON 17 \ FORT MASON 18 \ FORT MASON 20
# 1004446                           HILL ST \ SANCHEZ ST
# 1004511                       FARVIEW CT \ MARVIEW WAY
# 1004534                              17TH ST \ CAPP ST
# 1004694                        BATTERY ST \ VALLEJO ST
#
#                   Analysis Neighborhood Police District
# 0                               Mission         Mission
# 1                          McLaren Park       Ingleside
# 4                        Outer Richmond        Richmond
# 5                            Tenderloin      Tenderloin
# 6                          Hayes Valley        Northern
# ...                                 ...             ...
# 1004292                          Marina        Southern
# 1004446                      Noe Valley       Ingleside
# 1004511                      Twin Peaks         Mission
# 1004534                         Mission        Southern
# 1004694  Financial District/South Beach       Ingleside
#
# [14684 rows x 3 columns]

# %%
print(filtered[['Intersection', 'Analysis Neighborhood', 'Police District']].drop_duplicates().shape[0])
print(filtered['Intersection'].nunique())
# Out:
# 14684
# 6565

# %%
print(filtered['Incident Datetime'].min(), filtered['Incident Datetime'].max())
# Out:
# 2018/01/01 01:00:00 AM 2026/02/04 12:55:00 PM
